# %%
# %matplotlib notebook

import pandas
import matplotlib

# %%
df = pandas.read_csv("usage.csv.gz")

# %%
df.plot(x='DATE',y='USAGE')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-f93b21fa905c> in <module>()
#       1
# ----> 2 df.plot(kind='scatter',x='DATE',y='USAGE')
#
# c:\program files\python35\lib\site-packages\pandas\plotting\_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2625                           fontsize=fontsize, colormap=colormap, table=table,
#    2626                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2627                           sort_columns=sort_columns, **kwds)
#    2628     __call__.__doc__ = plot_frame.__doc__
#    2629
#
# ...

# %%
df
# Out:
#                  TYPE        DATE START TIME END TIME  USAGE UNITS NOTES
# 0      Electric usage  2016-01-01      00:00    00:59   0.72   kWh   NaN
# 1      Electric usage  2016-01-01      01:00    01:59   0.69   kWh   NaN
# 2      Electric usage  2016-01-01      02:00    02:59   0.71   kWh   NaN
# 3      Electric usage  2016-01-01      03:00    03:59   2.53   kWh   NaN
# 4      Electric usage  2016-01-01      04:00    04:59   0.80   kWh   NaN
# 5      Electric usage  2016-01-01      05:00    05:59   0.71   kWh   NaN
# 6      Electric usage  2016-01-01      06:00    06:59   0.79   kWh   NaN
# 7      Electric usage  2016-01-01      07:00    07:59   1.38   kWh   NaN
# 8      Electric usage  2016-01-01      08:00    08:59   0.91   kWh   NaN
# 9      Electric usage  2016-01-01      09:00    09:59  -0.29   kWh   NaN
# 10     Electric usage  2016-01-01      10:00    10:59  -0.72   kWh   NaN
# 11     Electric usage  2016-01-01      11:00    11:59  -0.48   kWh   NaN
# ...
